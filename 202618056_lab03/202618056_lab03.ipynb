# %%
import pandas as pd

# %%
df = pd.read_csv("hotel_bookings.csv")

# %%
df.head()
# Out:
#           hotel  is_canceled  lead_time  arrival_date_year arrival_date_month  \
# 0  Resort Hotel            0        342               2015               July
# 1  Resort Hotel            0        737               2015               July
# 2  Resort Hotel            0          7               2015               July
# 3  Resort Hotel            0         13               2015               July
# 4  Resort Hotel            0         14               2015               July
#
#    arrival_date_week_number  arrival_date_day_of_month  \
# 0                        27                          1
# 1                        27                          1
# 2                        27                          1
# 3                        27                          1
# 4                        27                          1
#
#    stays_in_weekend_nights  stays_in_week_nights  adults  ...  deposit_type  \
# 0                        0                     0       2  ...    No Deposit
# ...

# %%
df.shape
# Out:
# (119390, 32)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 119390 entries, 0 to 119389
# Data columns (total 32 columns):
#  #   Column                          Non-Null Count   Dtype
# ---  ------                          --------------   -----
#  0   hotel                           119390 non-null  object
#  1   is_canceled                     119390 non-null  int64
#  2   lead_time                       119390 non-null  int64
#  3   arrival_date_year               119390 non-null  int64
#  4   arrival_date_month              119390 non-null  object
#  5   arrival_date_week_number        119390 non-null  int64
#  6   arrival_date_day_of_month       119390 non-null  int64
#  7   stays_in_weekend_nights         119390 non-null  int64
#  8   stays_in_week_nights            119390 non-null  int64
#  9   adults                          119390 non-null  int64
#  10  children                        119386 non-null  float64
#  11  babies                          119390 non-null  int64
# ...

# %%
df.describe()
# Out:
#          is_canceled      lead_time  arrival_date_year  \
# count  119390.000000  119390.000000      119390.000000
# mean        0.370416     104.011416        2016.156554
# std         0.482918     106.863097           0.707476
# min         0.000000       0.000000        2015.000000
# 25%         0.000000      18.000000        2016.000000
# 50%         0.000000      69.000000        2016.000000
# 75%         1.000000     160.000000        2017.000000
# max         1.000000     737.000000        2017.000000
#
#        arrival_date_week_number  arrival_date_day_of_month  \
# count             119390.000000              119390.000000
# mean                  27.165173                  15.798241
# std                   13.605138                   8.780829
# min                    1.000000                   1.000000
# 25%                   16.000000                   8.000000
# 50%                   28.000000                  16.000000
# ...

# %%
df.dtypes
# Out:
# hotel                              object
# is_canceled                         int64
# lead_time                           int64
# arrival_date_year                   int64
# arrival_date_month                 object
# arrival_date_week_number            int64
# arrival_date_day_of_month           int64
# stays_in_weekend_nights             int64
# stays_in_week_nights                int64
# adults                              int64
# children                          float64
# babies                              int64
# meal                               object
# country                            object
# market_segment                     object
# distribution_channel               object
# is_repeated_guest                   int64
# previous_cancellations              int64
# previous_bookings_not_canceled      int64
# reserved_room_type                 object
# assigned_room_type                 object
# booking_changes                     int64
# ...

# %%
print(df["is_canceled"].value_counts())
# Out:
# is_canceled
# 0    75166
# 1    44224
# Name: count, dtype: int64

# %%
print(df["is_canceled"].value_counts(normalize=True) * 100)
# Out:
# is_canceled
# 0    62.958372
# 1    37.041628
# Name: proportion, dtype: float64

# %%
y = df["is_canceled"]

# %%
print(y.shape)
# Out:
# (119390,)

# %%
drop_cols = [
    "is_canceled",
    "reservation_status",
    "reservation_status_date",
    "name",
    "email",
    "phone-number",
    "credit_card"
]

drop_cols = [col for col in drop_cols if col in df.columns]
x = df.drop(columns=drop_cols)

# %%
numerical_cols = x.select_dtypes(include=["int64", "float64"]).columns.tolist()

categorical_cols = x.select_dtypes(include=["object"]).columns.tolist()

print("Shape of X:", x.shape)

print("\nNumerical Columns:")
print(numerical_cols)

print("\nCategorical Columns:")
print(categorical_cols)
# Out:
# Shape of X: (119390, 29)
#
# Numerical Columns:
# ['lead_time', 'arrival_date_year', 'arrival_date_week_number', 'arrival_date_day_of_month', 'stays_in_weekend_nights', 'stays_in_week_nights', 'adults', 'children', 'babies', 'is_repeated_guest', 'previous_cancellations', 'previous_bookings_not_canceled', 'booking_changes', 'agent', 'company', 'days_in_waiting_list', 'adr', 'required_car_parking_spaces', 'total_of_special_requests']
#
# Categorical Columns:
# ['hotel', 'arrival_date_month', 'meal', 'country', 'market_segment', 'distribution_channel', 'reserved_room_type', 'assigned_room_type', 'deposit_type', 'customer_type']

# %%
# Missing value count
missing_count = df.isnull().sum()

# Missing value percentage
missing_percentage = (missing_count / len(df)) * 100

# Create a summary table
missing_summary = pd.DataFrame({
    "Missing Count": missing_count,
    "Missing Percentage": missing_percentage
})

# Sort by missing count in descending order
missing_summary = missing_summary.sort_values(
    by="Missing Count",
    ascending=False
)

print(missing_summary)
# Out:
#                                 Missing Count  Missing Percentage
# company                                112593           94.306893
# agent                                   16340           13.686238
# country                                   488            0.408744
# children                                    4            0.003350
# arrival_date_month                          0            0.000000
# arrival_date_week_number                    0            0.000000
# hotel                                       0            0.000000
# is_canceled                                 0            0.000000
# stays_in_weekend_nights                     0            0.000000
# arrival_date_day_of_month                   0            0.000000
# adults                                      0            0.000000
# stays_in_week_nights                        0            0.000000
# babies                                      0            0.000000
# ...

# %%
missing_summary[missing_summary["Missing Count"] > 0]
# Out:
#           Missing Count  Missing Percentage
# company          112593           94.306893
# agent             16340           13.686238
# country             488            0.408744
# children              4            0.003350

# %%
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(16, 8))

sns.heatmap(
    df.isnull(),
    cbar=False,
    yticklabels=False,
    cmap="viridis"
)

plt.title("Missing Values Heatmap")
plt.xlabel("Columns")
plt.ylabel("Rows")
plt.show()

# %%
# Calculate missing percentage for each column
missing_percentage = df.isnull().mean() * 100

# Display columns with more than 50% missing values
high_missing = missing_percentage[missing_percentage > 50].sort_values(
    ascending=False
)

print("Columns with very high missingness:")
print(high_missing)
# Out:
# Columns with very high missingness:
# company    94.306893
# dtype: float64

# %%
# Drop company because more than 90% of its values are missing
df = df.drop(columns=["company"])

# %%
plt.figure(figsize=(16, 8))

sns.heatmap(
    df.isnull(),
    cbar=False,
    yticklabels=False,
    cmap="viridis"
)

plt.title("Missing Values Heatmap")
plt.xlabel("Columns")
plt.ylabel("Rows")
plt.show()

# %%
# Drop highly missing and leakage columns
drop_cols = [
    "company",
    "reservation_status",
    "reservation_status_date"
]

X = df.drop(columns=["is_canceled"] + 
            [col for col in drop_cols if col in df.columns])

print("Final X shape:", X.shape)
print("\nFinal feature columns:")
print(X.columns.tolist())
# Out:
# Final X shape: (119390, 28)
#
# Final feature columns:
# ['hotel', 'lead_time', 'arrival_date_year', 'arrival_date_month', 'arrival_date_week_number', 'arrival_date_day_of_month', 'stays_in_weekend_nights', 'stays_in_week_nights', 'adults', 'children', 'babies', 'meal', 'country', 'market_segment', 'distribution_channel', 'is_repeated_guest', 'previous_cancellations', 'previous_bookings_not_canceled', 'reserved_room_type', 'assigned_room_type', 'booking_changes', 'deposit_type', 'agent', 'days_in_waiting_list', 'customer_type', 'adr', 'required_car_parking_spaces', 'total_of_special_requests']

# %%
# Identify numerical columns from X
numerical_cols = X.select_dtypes(
    include=["int64", "float64"]
).columns.tolist()

print("Numerical columns:")
print(numerical_cols)
# Out:
# Numerical columns:
# ['lead_time', 'arrival_date_year', 'arrival_date_week_number', 'arrival_date_day_of_month', 'stays_in_weekend_nights', 'stays_in_week_nights', 'adults', 'children', 'babies', 'is_repeated_guest', 'previous_cancellations', 'previous_bookings_not_canceled', 'booking_changes', 'agent', 'days_in_waiting_list', 'adr', 'required_car_parking_spaces', 'total_of_special_requests']

# %%
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(18, 10))

sns.boxplot(data=X[numerical_cols])

plt.title("Boxplots of Numerical Features")
plt.xticks(rotation=90)
plt.ylabel("Values")
plt.show()

# %%
for col in numerical_cols:
    plt.figure(figsize=(8, 4))
    sns.boxplot(x=X[col])
    plt.title(f"Boxplot of {col}")
    plt.xlabel(col)
    plt.show()

# %%
# Store outlier information
outlier_summary = []

for col in numerical_cols:
    Q1 = X[col].quantile(0.25)
    Q3 = X[col].quantile(0.75)

    IQR = Q3 - Q1

    lower_bound = Q1 - 1.5 * IQR
    upper_bound = Q3 + 1.5 * IQR

    outliers = X[
        (X[col] < lower_bound) |
        (X[col] > upper_bound)
    ][col]

    outlier_summary.append({
        "Feature": col,
        "Q1": Q1,
        "Q3": Q3,
        "IQR": IQR,
        "Lower Bound": lower_bound,
        "Upper Bound": upper_bound,
        "Outlier Count": len(outliers),
        "Outlier Percentage": (len(outliers) / len(X)) * 100
    })

outlier_summary = pd.DataFrame(outlier_summary)

print(outlier_summary)
# Out:
#                            Feature       Q1      Q3     IQR  Lower Bound  \
# 0                        lead_time    18.00   160.0  142.00     -195.000
# 1                arrival_date_year  2016.00  2017.0    1.00     2014.500
# 2         arrival_date_week_number    16.00    38.0   22.00      -17.000
# 3        arrival_date_day_of_month     8.00    23.0   15.00      -14.500
# 4          stays_in_weekend_nights     0.00     2.0    2.00       -3.000
# 5             stays_in_week_nights     1.00     3.0    2.00       -2.000
# 6                           adults     2.00     2.0    0.00        2.000
# 7                         children     0.00     0.0    0.00        0.000
# 8                           babies     0.00     0.0    0.00        0.000
# 9                is_repeated_guest     0.00     0.0    0.00        0.000
# 10          previous_cancellations     0.00     0.0    0.00        0.000
# 11  previous_bookings_not_canceled     0.00     0.0    0.00        0.000
# ...

# %%
outlier_summary[
    outlier_summary["Outlier Count"] > 0
].sort_values(
    by="Outlier Count",
    ascending=False
)
# Out:
#                            Feature     Q1     Q3     IQR  Lower Bound  \
# 6                           adults   2.00    2.0    0.00        2.000
# 12                 booking_changes   0.00    0.0    0.00        0.000
# 7                         children   0.00    0.0    0.00        0.000
# 16     required_car_parking_spaces   0.00    0.0    0.00        0.000
# 10          previous_cancellations   0.00    0.0    0.00        0.000
# 9                is_repeated_guest   0.00    0.0    0.00        0.000
# 15                             adr  69.29  126.0   56.71      -15.775
# 14            days_in_waiting_list   0.00    0.0    0.00        0.000
# 11  previous_bookings_not_canceled   0.00    0.0    0.00        0.000
# 5             stays_in_week_nights   1.00    3.0    2.00       -2.000
# 0                        lead_time  18.00  160.0  142.00     -195.000
# 17       total_of_special_requests   0.00    1.0    1.00       -1.500
# ...

# %%
# Selected numerical features to check for extreme outliers
selected_features = [
    "lead_time",
    "adr",
    "adults",
    "children",
    "babies"
]

# Keep only columns that exist in X
selected_features = [
    col for col in selected_features if col in X.columns
]

# Create a copy before removing rows
X_clean = X.copy()
y_clean = y.copy()

# Boolean mask: True means keep the row
mask = pd.Series(True, index=X.index)

for col in selected_features:
    Q1 = X[col].quantile(0.25)
    Q3 = X[col].quantile(0.75)
    
    IQR = Q3 - Q1
    
    # Conservative bounds for extreme outliers
    lower_bound = Q1 - 3 * IQR
    upper_bound = Q3 + 3 * IQR
    
    # Keep rows within the bounds
    mask &= (
        X[col].isna() |
        ((X[col] >= lower_bound) & (X[col] <= upper_bound))
    )

# Count rows before removing outliers
rows_before = len(X)

# Remove only extreme outliers
X_clean = X.loc[mask].copy()
y_clean = y.loc[mask].copy()

# Count rows after removal
rows_after = len(X_clean)

# Number of rows removed
rows_removed = rows_before - rows_after

print("Rows before outlier removal:", rows_before)
print("Rows after outlier removal:", rows_after)
print("Total rows removed:", rows_removed)
print("Percentage removed:", round((rows_removed / rows_before) * 100, 2), "%")
# Out:
# Rows before outlier removal: 119390
# Rows after outlier removal: 81325
# Total rows removed: 38065
# Percentage removed: 31.88 %

# %% [markdown]
# ## 3

# %%
from sklearn.model_selection import train_test_split

# Train-test split
X_train, X_test, y_train, y_test = train_test_split(
    X_clean,
    y_clean,
    test_size=0.2,
    stratify=y_clean,
    random_state=42
)

# Check the shapes
print("X_train shape:", X_train.shape)
print("X_test shape:", X_test.shape)

print("y_train shape:", y_train.shape)
print("y_test shape:", y_test.shape)

# Check target distribution
print("\nTraining target distribution:")
print(y_train.value_counts(normalize=True))

print("\nTesting target distribution:")
print(y_test.value_counts(normalize=True))
# Out:
# X_train shape: (65060, 28)
# X_test shape: (16265, 28)
# y_train shape: (65060,)
# y_test shape: (16265,)
#
# Training target distribution:
# is_canceled
# 0    0.603458
# 1    0.396542
# Name: proportion, dtype: float64
#
# Testing target distribution:
# is_canceled
# 0    0.603443
# 1    0.396557
# Name: proportion, dtype: float64

# %%
import pandas as pd

from sklearn.model_selection import train_test_split
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline
from sklearn.impute import KNNImputer, SimpleImputer
from sklearn.preprocessing import StandardScaler, MinMaxScaler, OneHotEncoder


# --------------------------------------------------
# 1. Define X and y
# --------------------------------------------------


# Remove target, high-missingness column, and leakage columns
drop_cols = [
    "is_canceled",
    "company",
    "reservation_status",
    "reservation_status_date"
]

# Drop only columns that exist
drop_cols = [col for col in drop_cols if col in df.columns]

X = df.drop(columns=drop_cols)


# --------------------------------------------------
# 2. Identify numerical and categorical columns
# --------------------------------------------------

numerical_cols = X.select_dtypes(
    include=["int64", "float64"]
).columns.tolist()

categorical_cols = X.select_dtypes(
    include=["object"]
).columns.tolist()

print("Numerical columns:")
print(numerical_cols)

print("\nCategorical columns:")
print(categorical_cols)


# --------------------------------------------------
# 3. Train-Test Split
# --------------------------------------------------

X_train, X_test, y_train, y_test = train_test_split(
    X,
    y,
    test_size=0.2,
    stratify=y,
    random_state=42
)


# --------------------------------------------------
# 4. Categorical preprocessing
#    Same for both pipelines
# --------------------------------------------------

categorical_pipeline = Pipeline([
    ("imputer", SimpleImputer(strategy="most_frequent")),
    ("encoder", OneHotEncoder(handle_unknown="ignore"))
])


# --------------------------------------------------
# 5. Pipeline A
#    KNNImputer + StandardScaler
# --------------------------------------------------

numeric_pipeline_A = Pipeline([
    ("imputer", KNNImputer(n_neighbors=5)),
    ("scaler", StandardScaler())
])

preprocessor_A = ColumnTransformer([
    ("num", numeric_pipeline_A, numerical_cols),
    ("cat", categorical_pipeline, categorical_cols)
])


# --------------------------------------------------
# 6. Pipeline B
#    KNNImputer + MinMaxScaler
# --------------------------------------------------

numeric_pipeline_B = Pipeline([
    ("imputer", KNNImputer(n_neighbors=5)),
    ("scaler", MinMaxScaler())
])

preprocessor_B = ColumnTransformer([
    ("num", numeric_pipeline_B, numerical_cols),
    ("cat", categorical_pipeline, categorical_cols)
])


# --------------------------------------------------
# 7. Display information
# --------------------------------------------------

print("\nTraining set shape:", X_train.shape)
print("Testing set shape:", X_test.shape)

print("\nPipeline A:")
print(preprocessor_A)

print("\nPipeline B:")
print(preprocessor_B)
# Out:
# Numerical columns:
# ['lead_time', 'arrival_date_year', 'arrival_date_week_number', 'arrival_date_day_of_month', 'stays_in_weekend_nights', 'stays_in_week_nights', 'adults', 'children', 'babies', 'is_repeated_guest', 'previous_cancellations', 'previous_bookings_not_canceled', 'booking_changes', 'agent', 'days_in_waiting_list', 'adr', 'required_car_parking_spaces', 'total_of_special_requests']
#
# Categorical columns:
# ['hotel', 'arrival_date_month', 'meal', 'country', 'market_segment', 'distribution_channel', 'reserved_room_type', 'assigned_room_type', 'deposit_type', 'customer_type']
#
# Training set shape: (95512, 28)
# Testing set shape: (23878, 28)
#
# Pipeline A:
# ColumnTransformer(transformers=[('num',
#                                  Pipeline(steps=[('imputer', KNNImputer()),
#                                                  ('scaler', StandardScaler())]),
#                                  ['lead_time', 'arrival_date_year',
# ...

# %%
from sklearn.linear_model import LogisticRegression

logistic_A = Pipeline([
    ("preprocessor", preprocessor_A),
    ("model", LogisticRegression(max_iter=1000))
])

logistic_A.fit(X_train, y_train)
# Out:
# Pipeline(steps=[('preprocessor',
#                  ColumnTransformer(transformers=[('num',
#                                                   Pipeline(steps=[('imputer',
#                                                                    KNNImputer()),
#                                                                   ('scaler',
#                                                                    StandardScaler())]),
#                                                   ['lead_time',
#                                                    'arrival_date_year',
#                                                    'arrival_date_week_number',
#                                                    'arrival_date_day_of_month',
#                                                    'stays_in_weekend_nights',
#                                                    'stays_in_week_nights',
#                                                    'adults', 'children',
# ...

# %%
logistic_B = Pipeline([
    ("preprocessor", preprocessor_B),
    ("model", LogisticRegression(max_iter=1000))
])

logistic_B.fit(X_train, y_train)
# Out:
# Pipeline(steps=[('preprocessor',
#                  ColumnTransformer(transformers=[('num',
#                                                   Pipeline(steps=[('imputer',
#                                                                    KNNImputer()),
#                                                                   ('scaler',
#                                                                    MinMaxScaler())]),
#                                                   ['lead_time',
#                                                    'arrival_date_year',
#                                                    'arrival_date_week_number',
#                                                    'arrival_date_day_of_month',
#                                                    'stays_in_weekend_nights',
#                                                    'stays_in_week_nights',
#                                                    'adults', 'children',
# ...

# %%
from sklearn.tree import DecisionTreeClassifier
tree_A = Pipeline([
    ("preprocessor", preprocessor_A),
    ("model", DecisionTreeClassifier(random_state=42))
])

tree_A.fit(X_train, y_train)
# Out:
# Pipeline(steps=[('preprocessor',
#                  ColumnTransformer(transformers=[('num',
#                                                   Pipeline(steps=[('imputer',
#                                                                    KNNImputer()),
#                                                                   ('scaler',
#                                                                    StandardScaler())]),
#                                                   ['lead_time',
#                                                    'arrival_date_year',
#                                                    'arrival_date_week_number',
#                                                    'arrival_date_day_of_month',
#                                                    'stays_in_weekend_nights',
#                                                    'stays_in_week_nights',
#                                                    'adults', 'children',
# ...

# %%
tree_B = Pipeline([
    ("preprocessor", preprocessor_B),
    ("model", DecisionTreeClassifier(random_state=42))
])

tree_B.fit(X_train, y_train)
# Out:
# Pipeline(steps=[('preprocessor',
#                  ColumnTransformer(transformers=[('num',
#                                                   Pipeline(steps=[('imputer',
#                                                                    KNNImputer()),
#                                                                   ('scaler',
#                                                                    MinMaxScaler())]),
#                                                   ['lead_time',
#                                                    'arrival_date_year',
#                                                    'arrival_date_week_number',
#                                                    'arrival_date_day_of_month',
#                                                    'stays_in_weekend_nights',
#                                                    'stays_in_week_nights',
#                                                    'adults', 'children',
# ...

# %% [markdown]
# ## 5

# %%
from sklearn.metrics import (
    accuracy_score,
    precision_score,
    recall_score,
    f1_score,
    confusion_matrix,
    ConfusionMatrixDisplay
)
import pandas as pd
import matplotlib.pyplot as plt

# %%
models = {
    "Logistic Regression + Pipeline A": logistic_A,
    "Logistic Regression + Pipeline B": logistic_B,
    "Decision Tree + Pipeline A": tree_A,
    "Decision Tree + Pipeline B": tree_B
}

# %%
results = []

for name, model in models.items():

    # Predictions
    y_train_pred = model.predict(X_train)
    y_test_pred = model.predict(X_test)

    # Metrics
    train_accuracy = accuracy_score(y_train, y_train_pred)
    test_accuracy = accuracy_score(y_test, y_test_pred)

    precision = precision_score(y_test, y_test_pred)
    recall = recall_score(y_test, y_test_pred)
    f1 = f1_score(y_test, y_test_pred)

    # Train-test difference
    accuracy_difference = train_accuracy - test_accuracy

    results.append({
        "Model-Pipeline": name,
        "Training Accuracy": train_accuracy,
        "Testing Accuracy": test_accuracy,
        "Precision": precision,
        "Recall": recall,
        "F1-Score": f1,
        "Train-Test Difference": accuracy_difference
    })

# %%
results_df = pd.DataFrame(results)

# Round values for readability
results_df.iloc[:, 1:] = results_df.iloc[:, 1:].round(4)

print("Final Model Comparison:")
display(results_df)
# Out:
# Final Model Comparison:
#                      Model-Pipeline  Training Accuracy  Testing Accuracy  \
# 0  Logistic Regression + Pipeline A             0.8186            0.8183
# 1  Logistic Regression + Pipeline B             0.8129            0.8132
# 2        Decision Tree + Pipeline A             0.9963            0.8602
# 3        Decision Tree + Pipeline B             0.9963            0.8600
#
#    Precision  Recall  F1-Score  Train-Test Difference
# 0     0.8111  0.6642    0.7304                 0.0003
# 1     0.8085  0.6495    0.7203                -0.0003
# 2     0.8084  0.8159    0.8122                 0.1361
# 3     0.8078  0.8164    0.8121                 0.1363

# %%
# Best Logistic Regression result
logistic_results = results_df[
    results_df["Model-Pipeline"].str.startswith("Logistic Regression")
]

best_logistic = logistic_results.loc[
    logistic_results["F1-Score"].idxmax()
]

print("Best Logistic Regression:")
display(best_logistic)
# Out:
# Best Logistic Regression:
# Model-Pipeline           Logistic Regression + Pipeline A
# Training Accuracy                                  0.8186
# Testing Accuracy                                   0.8183
# Precision                                          0.8111
# Recall                                             0.6642
# F1-Score                                           0.7304
# Train-Test Difference                              0.0003
# Name: 0, dtype: object

# %%
# Best Decision Tree result
tree_results = results_df[
    results_df["Model-Pipeline"].str.startswith("Decision Tree")
]

best_tree = tree_results.loc[
    tree_results["F1-Score"].idxmax()
]

print("Best Decision Tree:")
display(best_tree)
# Out:
# Best Decision Tree:
# Model-Pipeline           Decision Tree + Pipeline A
# Training Accuracy                            0.9963
# Testing Accuracy                             0.8602
# Precision                                    0.8084
# Recall                                       0.8159
# F1-Score                                     0.8122
# Train-Test Difference                        0.1361
# Name: 2, dtype: object

# %%
best_logistic_name = best_logistic["Model-Pipeline"]
best_logistic_model = models[best_logistic_name]

y_pred_logistic = best_logistic_model.predict(X_test)

cm_logistic = confusion_matrix(y_test, y_pred_logistic)

disp = ConfusionMatrixDisplay(
    confusion_matrix=cm_logistic,
    display_labels=["Not Canceled", "Canceled"]
)

disp.plot()
plt.title(f"Confusion Matrix - {best_logistic_name}")
plt.show()

# %%
best_tree_name = best_tree["Model-Pipeline"]
best_tree_model = models[best_tree_name]

y_pred_tree = best_tree_model.predict(X_test)

cm_tree = confusion_matrix(y_test, y_pred_tree)

disp = ConfusionMatrixDisplay(
    confusion_matrix=cm_tree,
    display_labels=["Not Canceled", "Canceled"]
)

disp.plot()
plt.title(f"Confusion Matrix - {best_tree_name}")
plt.show()

# %%
for _, row in results_df.iterrows():

    difference = row["Train-Test Difference"]

    if difference > 0.10:
        comment = "Large gap: possible overfitting."
    elif difference > 0.05:
        comment = "Moderate gap: some possible overfitting."
    else:
        comment = "Small gap: limited evidence of overfitting."

    print(f"{row['Model-Pipeline']}: {comment}")
# Out:
# Logistic Regression + Pipeline A: Small gap: limited evidence of overfitting.
# Logistic Regression + Pipeline B: Small gap: limited evidence of overfitting.
# Decision Tree + Pipeline A: Large gap: possible overfitting.
# Decision Tree + Pipeline B: Large gap: possible overfitting.

# %% [markdown]
# task:-
# reduce features in above overfitting data

# %%
# Best overall model based on F1-score
best_overall = results_df.loc[results_df["F1-Score"].idxmax()]

print("Best Overall Model:")
print(best_overall)
# Out:
# Best Overall Model:
# Model-Pipeline           Decision Tree + Pipeline A
# Training Accuracy                            0.9963
# Testing Accuracy                             0.8602
# Precision                                    0.8084
# Recall                                       0.8159
# F1-Score                                     0.8122
# Train-Test Difference                        0.1361
# Name: 2, dtype: object

# %%
logistic_results = results_df[
    results_df["Model-Pipeline"].str.contains("Logistic Regression")
]

print("Logistic Regression comparison:")
display(logistic_results)
# Out:
# Logistic Regression comparison:
#                      Model-Pipeline  Training Accuracy  Testing Accuracy  \
# 0  Logistic Regression + Pipeline A             0.8186            0.8183
# 1  Logistic Regression + Pipeline B             0.8129            0.8132
#
#    Precision  Recall  F1-Score  Train-Test Difference
# 0     0.8111  0.6642    0.7304                 0.0003
# 1     0.8085  0.6495    0.7203                -0.0003

# %%
tree_results = results_df[
    results_df["Model-Pipeline"].str.contains("Decision Tree")
]

print("Decision Tree comparison:")
display(tree_results)
# Out:
# Decision Tree comparison:
#                Model-Pipeline  Training Accuracy  Testing Accuracy  Precision  \
# 2  Decision Tree + Pipeline A             0.9963            0.8602     0.8084
# 3  Decision Tree + Pipeline B             0.9963            0.8600     0.8078
#
#    Recall  F1-Score  Train-Test Difference
# 2  0.8159    0.8122                 0.1361
# 3  0.8164    0.8121                 0.1363

# %% [markdown]
# Task 6 — Final Observations
#
# Best Overall Result: The Decision Tree + Pipeline A achieved the best overall performance, with a testing accuracy of 86.02% and an F1-score of 0.8122. It performed better than Logistic Regression in terms of overall classification performance.
#
# Effect of Scaling on Logistic Regression: StandardScaler performed slightly better than MinMaxScaler for Logistic Regression. Pipeline A achieved a testing accuracy of 81.83% and an F1-score of 0.7304, compared with 81.32% and 0.7203 for Pipeline B. Thus, StandardScaler had a small but noticeable positive effect.
#
# Effect of Scaling on Decision Tree: Scaling had almost no effect on Decision Tree performance. Pipeline A and Pipeline B achieved nearly identical testing accuracy (86.02% vs. 86.00%) and F1-scores (0.8122 vs. 0.8121). This is expected because Decision Trees are generally insensitive to feature scaling.
#
# Overfitting in Decision Tree: Both Decision Tree models show significant overfitting. Their training accuracy is 99.63%, while testing accuracy is around 86%, resulting in a large train-test gap of approximately 13.6 percentage points. This indicates that the trees are fitting the training data too closely.
#
# Generalization of Logistic Regression: Logistic Regression shows much better generalization, with almost no difference between training and testing accuracy. Pipeline A has a gap of only 0.03 percentage points, while Pipeline B has a negligible difference of -0.03 percentage points. However, its overall testing performance is lower than that of the Decision Tree.
